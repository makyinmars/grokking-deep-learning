# %%
knob_weight = 0.5
input = 0.5
goal_pred = 0.8

pred = input * knob_weight

error = (pred - goal_pred) ** 2

print(error)
# Out:
# 0.30250000000000005

# %%
# Error
weight = 0.1
lr = 0.01

def neural_network(input, weight):
    prediction = input * weight
    return prediction

# PREDICT: Making a prediction and evaluating the error
number_of_toes = [8.5]
win_or_lose_binary = [1] # (won!!)

input = number_of_toes[0]
true = win_or_lose_binary[0]

pred = neural_network(input, weight)

error = (pred - true) ** 2
print(error)

p_up = neural_network(input, weight + lr)

e_up = (p_up - true) ** 2

print("P up", e_up)

p_dn = neural_network(input, weight - lr)

e_dn = (p_dn - true) ** 2

print("P down", e_dn)

## Compare and learn: Comparing the errors and setting the new weight
print("Weight before compare and learn", weight)
if(error > e_dn or error > e_up):
    if (e_dn < e_up):
        weight = weight - lr
    else:
        weight = weight + lr

print("Weight after compare and learn", weight)
# Out:
# 0.022499999999999975
# P up 0.004224999999999993
# P down 0.05522499999999994
# Weight before compare and learn 0.1
# Weight after compare and learn 0.11

# %% [markdown]
# ## Changes with the simples form of learning - Hot or Cold

# %%
weight = 0.5
input = 0.5
goal_prediction = 0.8

step_amount = 0.8

for iteration in range(1101):
    prediction = input * weight

    error = (prediction - goal_prediction) ** 2

    print("Error:", str(error) + " Prediction:" + str(prediction))

    up_prediction = input * (weight + step_amount)
    up_error = (goal_prediction - up_prediction) ** 2

    down_prediction = input * (weight - step_amount)
    down_error = (goal_prediction - down_prediction) ** 2

    if(down_error < up_error):
        weight = weight - step_amount

    if(down_error > up_error):
        weight = weight + step_amount
# Out:
# Error: 0.30250000000000005 Prediction:0.25
# Error: 0.022500000000000006 Prediction:0.65
# Error: 0.0625 Prediction:1.05
# Error: 0.022500000000000006 Prediction:0.65
# Error: 0.0625 Prediction:1.05
# Error: 0.022500000000000006 Prediction:0.65
# Error: 0.0625 Prediction:1.05
# Error: 0.022500000000000006 Prediction:0.65
# Error: 0.0625 Prediction:1.05
# Error: 0.022500000000000006 Prediction:0.65
# Error: 0.0625 Prediction:1.05
# Error: 0.022500000000000006 Prediction:0.65
# Error: 0.0625 Prediction:1.05
# Error: 0.022500000000000006 Prediction:0.65
# Error: 0.0625 Prediction:1.05
# Error: 0.022500000000000006 Prediction:0.65
# Error: 0.0625 Prediction:1.05
# Error: 0.022500000000000006 Prediction:0.65
# Error: 0.0625 Prediction:1.05
# Error: 0.022500000000000006 Prediction:0.65
# Error: 0.0625 Prediction:1.05
# Error: 0.022500000000000006 Prediction:0.65
# Error: 0.0625 Prediction:1.05
# Error: 0.022500000000000006 Prediction:0.65
# Error: 0.0625 Prediction:1.05
# ...

# %% [markdown]
# # Calculating both direction and amount from error

# %%
weight = 0.5
goal_pred = 0.8
input = 0.5

for iteration in range(20):
    pred = input * weight
    error = (pred - goal_pred) ** 2
    direction_and_amount = (pred - goal_pred) * input
    weight = weight - direction_and_amount

    print("Error:" + str(error) + " Prediction:" + str(pred))
# Out:
# Error:0.30250000000000005 Prediction:0.25
# Error:0.17015625000000004 Prediction:0.3875
# Error:0.095712890625 Prediction:0.49062500000000003
# Error:0.05383850097656251 Prediction:0.56796875
# Error:0.03028415679931642 Prediction:0.6259765625
# Error:0.0170348381996155 Prediction:0.669482421875
# Error:0.00958209648728372 Prediction:0.70211181640625
# Error:0.005389929274097089 Prediction:0.7265838623046875
# Error:0.0030318352166796153 Prediction:0.7449378967285156
# Error:0.0017054073093822882 Prediction:0.7587034225463867
# Error:0.0009592916115275371 Prediction:0.76902756690979
# Error:0.0005396015314842384 Prediction:0.7767706751823426
# Error:0.000303525861459885 Prediction:0.7825780063867569
# Error:0.00017073329707118678 Prediction:0.7869335047900676
# Error:9.603747960254256e-05 Prediction:0.7902001285925507
# Error:5.402108227642978e-05 Prediction:0.7926500964444131
# Error:3.038685878049206e-05 Prediction:0.7944875723333098
# ...

# %% [markdown]
# # One iteration of gradient descent

# %%
weight = 0.1
alpha = 0.01

def neural_network(input, weight):
    prediction = input * weight
    return prediction

number_of_toes = [8.5]
win_or_lose_binary = [1]

input = number_of_toes[0]
goal_pred = win_or_lose_binary[0]

pred = neural_network(input, weight)

# Forces the raw error to be positive by multiplying
# it by itself. Negative error won't make sense.
error = (pred - goal_pred) ** 2

# Node delta
delta = pred - goal_pred

# Weight delta
weight_delta = input * delta

alpha = 0.01

weight -= weight_delta * alpha

# %% [markdown]
# # Learning is just reducing error

# %%
weight, goal_pred, input = (0.0, 0.8, 0.5)

for iteration in range(4):
    pred = input * weight
    error = (pred - goal_pred) ** 2
    delta = pred - goal_pred
    weight_delta = delta * input
    weight = weight - weight_delta
    print("Error:" + str(error) + " Prediction:" + str(pred))
# Out:
# Error:0.6400000000000001 Prediction:0.0
# Error:0.3600000000000001 Prediction:0.2
# Error:0.2025 Prediction:0.35000000000000003
# Error:0.11390625000000001 Prediction:0.4625

# %% [markdown]
# # Breaking gradient descent

# %%
weight = 0.5
goal_pred = 0.98
input = 0.5 

for iteration in range(20):
    pred = input * weight
    error = (pred - goal_pred) ** 2
    delta = pred - goal_pred
    weight_delta = input * delta
    weight = weight - weight_delta
    print("Error:" + str(error) + " Prediction:" + str(pred))
# Out:
# Error:0.5328999999999999 Prediction:0.25
# Error:0.29975625 Prediction:0.4325
# Error:0.168612890625 Prediction:0.569375
# Error:0.0948447509765625 Prediction:0.67203125
# Error:0.053350172424316396 Prediction:0.7490234375
# Error:0.030009471988677972 Prediction:0.806767578125
# Error:0.01688032799363137 Prediction:0.85007568359375
# Error:0.009495184496417645 Prediction:0.8825567626953125
# Error:0.005341041279234921 Prediction:0.9069175720214844
# Error:0.003004335719569643 Prediction:0.9251881790161133
# Error:0.0016899388422579264 Prediction:0.9388911342620849
# Error:0.0009505905987700836 Prediction:0.9491683506965637
# Error:0.0005347072118081708 Prediction:0.9568762630224228
# Error:0.00030077280664209604 Prediction:0.9626571972668171
# Error:0.00016918470373617975 Prediction:0.9669928979501128
# Error:9.516639585160111e-05 Prediction:0.9702446734625846
# Error:5.353109766652522e-05 Prediction:0.9726835050969385
# Error:3.0111242437420434e-05 Prediction:0.9745126288227038
# ...

# %% [markdown]
# # Adding alpha

# %%
weight = 0.5
goal_pred = 0.8
input = 2
alpha = 0.1

for iteration in range(20):
    pred = input * weight
    error = (pred - goal_pred) ** 2
    derivative = input * (pred - goal_pred)
    weight = weight - (alpha * derivative)

    print ("Error:" + str(error) + " Prediction:" + str(pred) + " Weight:" + str(weight))
# Out:
# Error:0.03999999999999998 Prediction:1.0 Weight:0.46
# Error:0.0144 Prediction:0.92 Weight:0.436
# Error:0.005183999999999993 Prediction:0.872 Weight:0.42160000000000003
# Error:0.0018662400000000014 Prediction:0.8432000000000001 Weight:0.41296000000000005
# Error:0.0006718464000000028 Prediction:0.8259200000000001 Weight:0.407776
# Error:0.00024186470400000033 Prediction:0.815552 Weight:0.4046656
# Error:8.70712934399997e-05 Prediction:0.8093312 Weight:0.40279936
# Error:3.134566563839939e-05 Prediction:0.80559872 Weight:0.401679616
# Error:1.1284439629823931e-05 Prediction:0.803359232 Weight:0.4010077696
# Error:4.062398266736526e-06 Prediction:0.8020155392 Weight:0.40060466176000004
# Error:1.4624633760252567e-06 Prediction:0.8012093235200001 Weight:0.40036279705600003
# Error:5.264868153690924e-07 Prediction:0.8007255941120001 Weight:0.40021767823360005
# Error:1.8953525353291194e-07 Prediction:0.8004353564672001 Weight:0.40013060694016006
# ...
